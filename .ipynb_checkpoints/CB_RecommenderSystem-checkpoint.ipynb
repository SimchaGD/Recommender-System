# %% [markdown]
# # Recommender Systems
# ## Writing A Machine Learning Algorithm for Recommending Movies
#
# In dit script probeer ik een algoritme te schrijven die de beoordeling van films gaat voorspellen voor mensen. Recommender Systems worden gebruikt door bedrijven zoals YouTube en Netflix om jou langer op hun platform te houden. Ook kan het gebruikt worden door online kledingwinkels die willen voorspellen welke kleding jij leuk vindt.
#
# De dataset die wordt gebruikt is de MovieLens database. Deze is te vinden op [grouplens.org/](https://grouplens.org/datasets/movielens/). Daarnaast volg ik een stappenplan die is beschreven in [towardsdatascience.com](https://towardsdatascience.com/how-to-build-a-simple-recommender-system-in-python-375093c3fb7d.)

# %%
import pandas as pd 
import numpy as np
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
# Het inladen van de dataset. Kies voor de kleine of de grote dataset aan de hand van je doel. 
# De grote dataset duurt lang om in te laden, maar zal wel betere resultaten leveren
BigDataSet = False
DataSet = "data" if BigDataSet else "data_small"
df = pd.read_csv(DataSet + '/ratings.csv', sep=',', names=['userID','movieID','rating','timestamp'], header = 0)
df.head()
# Out:
#    userID  movieID  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# Door de movies.csv dataset samen te voegen met de ratings.csv kunnen we de ratings koppelen aan een film

# %%
movieTitles = pd.read_csv(DataSet + '/movies.csv', names=['movieID','title','genres'], header = 0)
df = pd.merge(df, movieTitles, on='movieID')
df.head()
# Out:
#    userID  movieID  rating   timestamp             title  \
# 0       1        1     4.0   964982703  Toy Story (1995)
# 1       5        1     4.0   847434962  Toy Story (1995)
# 2       7        1     4.5  1106635946  Toy Story (1995)
# 3      15        1     2.5  1510577970  Toy Story (1995)
# 4      17        1     4.5  1305696483  Toy Story (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1  Adventure|Animation|Children|Comedy|Fantasy
# 2  Adventure|Animation|Children|Comedy|Fantasy
# 3  Adventure|Animation|Children|Comedy|Fantasy
# 4  Adventure|Animation|Children|Comedy|Fantasy

# %% [markdown]
# Dit is wat elke kolom betekent:
# - `userID` is de ID van elke gebruiker.
# - `movieID` is de ID van elke film.
# - `rating` is de beoordeling van de gebruiker `userID` op film `movieID`. Dit kan een waarde zijn tussen 1 en 5
# - `timestamp` is de tijd dat de film beoordeeld was
# - `title` is de naam van de film en uit welk jaar die kwam
# - `genres` zijn de verschillende soorten genres van de film
#
# Met de commando's `describe` krijgen we een samenvatting van onze dataset.

# %%
df.describe(include='all')
# Out:
#                userID        movieID         rating     timestamp  \
# count   100836.000000  100836.000000  100836.000000  1.008360e+05
# unique            NaN            NaN            NaN           NaN
# top               NaN            NaN            NaN           NaN
# freq              NaN            NaN            NaN           NaN
# mean       326.127564   19435.295718       3.501557  1.205946e+09
# std        182.618491   35530.987199       1.042529  2.162610e+08
# min          1.000000       1.000000       0.500000  8.281246e+08
# 25%        177.000000    1199.000000       3.000000  1.019124e+09
# 50%        325.000000    2991.000000       3.500000  1.186087e+09
# 75%        477.000000    8122.000000       4.000000  1.435994e+09
# max        610.000000  193609.000000       5.000000  1.537799e+09
#
#                       title  genres
# count                100836  100836
# unique                 9719     951
# top     Forrest Gump (1994)  Comedy
# freq                    329    7196
# mean                    NaN     NaN
# std                     NaN     NaN
# min                     NaN     NaN
# 25%                     NaN     NaN
# 50%                     NaN     NaN
# 75%                     NaN     NaN
# max                     NaN     NaN

# %% [markdown]
# We zien wat interessante dingen. De dataset heeft 100837 beoordelingen met 611 unieke gebruikers en 9725 unieke films. Daarnaast is de meest beoordeelde film Forrest Gump uit 1994. Deze film is 329 keer beoordeeld.
#
# Nu kunnnen we een data frame maken met de gemiddelde beoordeling en het aantal beoordelingen. Hiermee is het mogelijk een correlatie coefficient uit te rekenen. Om deze dataset te krijgen gebruiken we de `groupby` functie. We groeperen op de `title` en pakken het gemiddelde van `rating`.

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())
ratings.head()
# Out:
#                                          rating
# title
# '71 (2014)                                  4.0
# 'Hellboy': The Seeds of Creation (2004)     4.0
# 'Round Midnight (1986)                      3.5
# 'Salem's Lot (2004)                         5.0
# 'Til There Was You (1997)                   4.0

# %% [markdown]
# Daarnaast willen we een kolom met de `numberOfRatings` waarin staat hoeveel ratings een film heeft gekregen. Dit doen we ook met de `groupby` functie, maar  we kiezen ervoor om de ratings te tellen met `count`.

# %%
ratings['numberOfRatings'] = df.groupby('title')['rating'].count()
ratings.head()
# Out:
#                                          rating  numberOfRatings
# title
# '71 (2014)                                  4.0                1
# 'Hellboy': The Seeds of Creation (2004)     4.0                1
# 'Round Midnight (1986)                      3.5                2
# 'Salem's Lot (2004)                         5.0                1
# 'Til There Was You (1997)                   4.0                2

# %%
ratings['rating'].hist(bins=50)

# %%
ratings['numberOfRatings'].hist(bins=50)

# %%
import seaborn as sns
sns.jointplot(x='rating', y='numberOfRatings', data=ratings)

# %% [markdown]
# Deze diagram geeft een belangrijk feit weer over onze data. Hoe meer ratings de film heeft gehad, hoe groteer de kans is dat deze film een goeie rating heeft.
#
# Laten we de Content Based recommender system maken. Het format van een tabel zoals weergegeven in de coursera course van Andrew Ng is bij ons een draaitafel. Deze staat hieronder weergegeven. De waarde met `NaN` zijn de films die de gebruiker nog niet heeft beoordeeld.

# %%
movie_matrix = df.pivot_table(index='userID', columns='title', values='rating')
movie_matrix.head()
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userID
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userID
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userID
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userID
# 1                      NaN                   NaN                          NaN
# 2                      NaN                   NaN                          NaN
# 3                      NaN                   NaN                          NaN
# 4                      NaN                   NaN                          NaN
# 5                      NaN                   NaN                          NaN
#
# title   *batteries not included (1987)  \
# userID
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
#
# title                     ...                      Zulu (2013)  [REC] (2007)  \
# userID                    ...
# 1                         ...                              NaN           NaN
# 2                         ...                              NaN           NaN
# 3                         ...                              NaN           NaN
# 4                         ...                              NaN           NaN
# 5                         ...                              NaN           NaN
#
# title   [REC]² (2009)  [REC]³ 3 Génesis (2012)  \
# userID
# 1                 NaN                      NaN
# 2                 NaN                      NaN
# 3                 NaN                      NaN
# 4                 NaN                      NaN
# 5                 NaN                      NaN
#
# title   anohana: The Flower We Saw That Day - The Movie (2013)  \
# userID
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
#
# title   eXistenZ (1999)  xXx (2002)  xXx: State of the Union (2005)  \
# userID
# 1                   NaN         NaN                             NaN
# 2                   NaN         NaN                             NaN
# 3                   NaN         NaN                             NaN
# 4                   NaN         NaN                             NaN
# 5                   NaN         NaN                             NaN
#
# title   ¡Three Amigos! (1986)  À nous la liberté (Freedom for Us) (1931)
# userID
# 1                         4.0                                        NaN
# 2                         NaN                                        NaN
# 3                         NaN                                        NaN
# 4                         NaN                                        NaN
# 5                         NaN                                        NaN
#
# [5 rows x 9719 columns]

# %% [markdown]
# Laten we even kijken naar twee van de meest beoordeelde films om een simpele recommendation system te maken.

# %%
ratings.sort_values('numberOfRatings', ascending=False).head(10)
# Out:
#                                              rating  numberOfRatings
# title
# Forrest Gump (1994)                        4.164134              329
# Shawshank Redemption, The (1994)           4.429022              317
# Pulp Fiction (1994)                        4.197068              307
# Silence of the Lambs, The (1991)           4.161290              279
# Matrix, The (1999)                         4.192446              278
# Star Wars: Episode IV - A New Hope (1977)  4.231076              251
# Jurassic Park (1993)                       3.750000              238
# Braveheart (1995)                          4.031646              237
# Terminator 2: Judgment Day (1991)          3.970982              224
# Schindler's List (1993)                    4.225000              220

# %% [markdown]
# Laten we er vanuit gaan dat de gebruiker *Air Force One* en *Contact* heeft gekeken. Deze gebruiker willen we nieuwe films aanraden op basis van deze twee films. Het doel is om te kijken naar films die lijken op deze twee films. Dit kan je doen door de correlatie te vinden tussen deze twee films en de beoordelingen over de rest van de dataset.

# %%
AFO_user_rating = movie_matrix['Air Force One (1997)']
contact_user_rating = movie_matrix['Contact (1997)']

# %%
print(AFO_user_rating.head())
print(contact_user_rating.head())
# Out:
# userID
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: Air Force One (1997), dtype: float64
# userID
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: Contact (1997), dtype: float64

# %% [markdown]
# Om de correlatie te berekenen tussen twee dataframes gebruiken we `corrwidth`. Deze functie berekent de correlatie tussen rijen of kolommen. Hieronder wordt de functie gebruikt om de correlatie tussen de film beoordelingen en de beoordelingen van Air Force One.

# %%
similar_to_air_force_one=movie_matrix.corrwith(AFO_user_rating)

# %%
similar_to_air_force_one.sort_values(ascending=False).head(20)
# Out:
# title
# Let It Ride (1989)                    1.0
# Larry Crowne (2011)                   1.0
# Battlestar Galactica: Razor (2007)    1.0
# Be Cool (2005)                        1.0
# Andre (1994)                          1.0
# Child's Play 2 (1990)                 1.0
# Dr. T and the Women (2000)            1.0
# Slither (2006)                        1.0
# Hairspray (2007)                      1.0
# Guarding Tess (1994)                  1.0
# Out to Sea (1997)                     1.0
# Sniper (1993)                         1.0
# Guard, The (2011)                     1.0
# Grey Zone, The (2001)                 1.0
# Song of the South (1946)              1.0
# Great Muppet Caper, The (1981)        1.0
# Sorcerer's Apprentice, The (2010)     1.0
# 9 (2009)                              1.0
# Malcolm X (1992)                      1.0
# Cinderella Story, A (2004)            1.0
# dtype: float64

# %% [markdown]
# Zoals je ziet zijn er veel films die lijken op Air Force One. Laten we kijken of er ook een correlatie is met de beoordelingen van Contact.

# %%
similar_to_contact = movie_matrix.corrwith(contact_user_rating)

# %%
similar_to_contact.sort_values(ascending=False).head(20)
# Out:
# title
# Norma Rae (1979)                                 1.0
# Batman Beyond: Return of the Joker (2000)        1.0
# Stalingrad (1993)                                1.0
# Host, The (Gwoemul) (2006)                       1.0
# Doom Generation, The (1995)                      1.0
# Head of State (2003)                             1.0
# Guarding Tess (1994)                             1.0
# Precious (2009)                                  1.0
# Vatel (2000)                                     1.0
# Speed Racer (2008)                               1.0
# Dragnet (1987)                                   1.0
# Maze Runner, The (2014)                          1.0
# Dragonfly (2002)                                 1.0
# Batman: Gotham Knight (2008)                     1.0
# Me Myself I (2000)                               1.0
# Me and You and Everyone We Know (2005)           1.0
# View from the Top (2003)                         1.0
# Doctor Strange (2016)                            1.0
# Divine Secrets of the Ya-Ya Sisterhood (2002)    1.0
# Now, Voyager (1942)                              1.0
# dtype: float64

# %% [markdown]
# Zoals we eerder zagen hadden sommige films niet heel veel beoordelingen. Door deze er uit te halen en de resultaten in dataframes te stoppen ziet het er wat beter uit.

# %%
corr_contact = pd.DataFrame(similar_to_contact, columns=['Correlation'])
corr_contact.dropna(inplace=True)
#Het lastige is dat we nog steeds niet zien hoeveel ratings elke film heeft. 
#Daardoor is het nogsteeds mogelijk dat de correlatie is gebaseerd op 1 beoordeling. 
#We kunnen de dataset joinen met de `NumberOfRatings`
corr_contact = corr_contact.join(ratings['numberOfRatings'])
corr_contact.sort_values('Correlation',ascending=False).head()
# Out:
#                                          Correlation  numberOfRatings
# title
# Grown Ups (2010)                                 1.0               10
# Armour of God (Long xiong hu di) (1987)          1.0                6
# Arthur (2011)                                    1.0                6
# Thousand Acres, A (1997)                         1.0                2
# Mosquito Coast, The (1986)                       1.0               10

# %%
corr_AFO = pd.DataFrame(similar_to_air_force_one, columns=['Correlation'])
corr_AFO.dropna(inplace=True)
#Het lastige is dat we nog steeds niet zien hoeveel ratings elke film heeft. 
#Daardoor is het nogsteeds mogelijk dat de correlatie is gebaseerd op 1 beoordeling. 
#We kunnen de dataset joinen met de `NumberOfRatings`
corr_AFO = corr_AFO.join(ratings['numberOfRatings'])
corr_AFO.sort_values('Correlation',ascending=False).head()
# Out:
#                            Correlation  numberOfRatings
# title
# Dope (2015)                        1.0                6
# Laws of Attraction (2004)          1.0                4
# Julie & Julia (2009)               1.0               12
# Song of the South (1946)           1.0                6
# Carnage (2011)                     1.0                4

# %% [markdown]
# Het lastige is dat we nog steeds niet zien hoeveel ratings elke film heeft. Daardoor is het nogsteeds mogelijk dat de correlatie is gebaseerd op 1 beoordeling. We kunnen de dataset joinen met de `NumberOfRatings`
